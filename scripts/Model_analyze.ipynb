# %% [markdown]
# # LSTM Cluster Result Analysis
#
# This notebook analyzes the performance and results of the trained LSTM classification models for traffic congestion clustering.
# It focuses on evaluating model loss, accuracy, and prediction–label consistency across different road segments.
#
# ## Overview
# - **Objective:** Evaluate and visualize the model’s learning behavior and classification performance.
# - **Models:** Trained using `train_lstm_cluster.py` for *Causeway* and *Second Link* segments.
# - **Source of Data:** Training logs generated by `train_lstm_cluster.py`, containing:
#   - `history`: training and validation loss/accuracy per epoch
#   - `metrics`: validation accuracy per step and overall accuracy
# - **Outputs:**
#   - Loss and accuracy curves across epochs.
#
# ## Workflow
# 1. Load the saved `.json` training logs from the model directory.
# 2. Plot and compare training/validation loss and accuracy curves.

# %%
import json
import matplotlib.pyplot as plt
from pathlib import Path


log_path = Path("artifacts/model_cluster/causeway_train_log.json")


with open(log_path, "r", encoding="utf-8") as f:
    log_data = json.load(f)


history = log_data["history"]

# Draw Loss curve
plt.figure(figsize=(8,5))
plt.plot(history["loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Val Loss")
plt.title("LSTM Training Loss Curve(causeway)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# Draw Accuracy curve
plt.figure(figsize=(8,5))
plt.plot(history["acc"], label="Train Accuracy")
plt.plot(history["val_acc"], label="Val Accuracy")
plt.title("LSTM Training Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
log_path = Path("artifacts/model_cluster/second_link_train_log.json")


with open(log_path, "r", encoding="utf-8") as f:
    log_data = json.load(f)

history = log_data["history"]

# Draw Loss curve
plt.figure(figsize=(8,5))
plt.plot(history["loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Val Loss")
plt.title("LSTM Training Loss Curve(Second_link)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# Draw Accuracy curve
plt.figure(figsize=(8,5))
plt.plot(history["acc"], label="Train Accuracy")
plt.plot(history["val_acc"], label="Val Accuracy")
plt.title("LSTM Training Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()
